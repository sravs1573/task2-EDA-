# %%
import pandas as pd

# Load your cleaned dataset
df = pd.read_csv("/content/titanic_cleaned.csv")

# View the first few rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            7         0       1
#
#                                            Name     Sex       Age  SibSp  \
# 0                       Braund, Mr. Owen Harris    male -0.530377      1
# 1                        Heikkinen, Miss. Laina  female -0.254825      0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.365167      1
# 3                      Allen, Mr. William Henry    male  0.365167      0
# 4                       McCarthy, Mr. Timothy J    male  1.674039      0
#
#    Parch            Ticket      Fare Cabin Embarked
# 0      0         A/5 21171 -0.502445   NaN        S
# 1      0  STON/O2. 3101282 -0.488854   NaN        S
# 2      0            113803  0.420730  C123        S
# 3      0            373450 -0.486337   NaN        S
# 4      0             17463  0.395814   E46        S

# %%
# Summary statistics for all numeric columns
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   607.000000  607.000000  607.000000  607.000000  607.000000
# mean    449.467875    0.360791    2.433278   -0.100054    0.495881
# std     262.357612    0.480626    0.734631    0.925099    0.959355
# min       1.000000    0.000000    1.000000   -2.016979    0.000000
# 25%     212.500000    0.000000    2.000000   -0.668153    0.000000
# 50%     447.000000    0.000000    3.000000   -0.117049    0.000000
# 75%     683.500000    1.000000    3.000000    0.434055    1.000000
# max     891.000000    1.000000    3.000000    2.362918    5.000000
#
#             Parch        Fare
# count  607.000000  607.000000
# mean     0.403624   -0.267204
# std      0.852207    0.285598
# min      0.000000   -0.648422
# 25%      0.000000   -0.488854
# 50%      0.000000   -0.386671
# 75%      0.500000   -0.119886
# max      6.000000    0.746912

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for Age
sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Distribution of Age")
plt.xlabel("Age (Standardized)")
plt.ylabel("Frequency")
plt.show()

# Boxplot for Age
sns.boxplot(x=df['Age'])
plt.title("Boxplot of Age")
plt.xlabel("Age (Standardized)")
plt.show()

# %%
# Correlation matrix heatmap
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df[['Age', 'Fare', 'Survived', 'Pclass']])
plt.show()
